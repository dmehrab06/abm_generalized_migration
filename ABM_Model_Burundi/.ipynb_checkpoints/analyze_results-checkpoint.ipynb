# %%
import pandas as pd
from file_paths_and_consts import *
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import datetime
from matplotlib import rcParams
from matplotlib.colors import LinearSegmentedColormap
plt.style.use('classic')
import seaborn as sns
import geopandas as gpd
import random
sns.set()

SEED_VALUE = 590
random.seed(SEED_VALUE)

OUTPUT_DIR
# Out:
# '/project/biocomplexity/UKR_forecast/migration_data/output_data/'

# %%
ROLLING = 7
conflict_data_file = UNCLEANED_DATA_DIR+'2015-01-01-2016-12-31-Burundi.csv'
refugee_data_file = UNCLEANED_DATA_DIR+'burundi_refugees.csv'
geo_shp_file = UNCLEANED_DATA_DIR+'burundi_shp/geoBoundaries-BDI-ADM2.shp'

conflict_data = pd.read_csv(conflict_data_file)
conflict_data['time'] = pd.to_datetime(conflict_data['event_date'])
conflict_data = conflict_data.sort_values(by='time')
conflict_count = conflict_data[['time','fatalities']].groupby('time')['fatalities'].count().reset_index()
conflict_count['fatalities'] = conflict_count['fatalities'].cumsum()
conflict_count['fatalities'] = conflict_count['fatalities'].rolling(7).mean()
conflict_count = conflict_count.dropna(subset=['fatalities'])

refugee_data = pd.read_csv(refugee_data_file)
refugee_data['time'] = pd.to_datetime(refugee_data['time'])
refugee_data = refugee_data.sort_values(by='time')
refugee_data['refugee'] = refugee_data['refugee'].rolling(7).mean()
refugee_data = refugee_data.dropna(subset=['refugee'])
# refugee_data['refugee'] = refugee_data['refugee'].diff()
# refugee_data = refugee_data.dropna(subset=['refugee'])

burundi_gdf = gpd.read_file(geo_shp_file)

fig,ax = plt.subplots(1,2,figsize=(15,5),gridspec_kw={'width_ratios': [3, 1]})
plt.xticks(rotation=60)
rcParams["font.family"] = "calibri"
rcParams["font.size"] = 12
rcParams["axes.labelsize"] = 16
rcParams["axes.titlesize"] = 20
rcParams["xtick.labelsize"] = 14
rcParams["ytick.labelsize"] = 14

ax2 = ax[0].twinx()
ax2.plot(refugee_data['time'],refugee_data['refugee'],marker='X',linewidth=2,color='green',label='Observed Refugee')
ax[0].plot(conflict_count['time'],conflict_count['fatalities'],marker='o',linewidth=2,label='# Daily Events')
ax[0].set_xlim([datetime.date(2015, 5, 1), datetime.date(2015, 8, 31)])
#ax.set_ylim([conflict_count['fatalities'].min()-5,conflict_count['fatalities'].max()+5])
#ax2.set_ylim([refugee_data['refugee'].min()-500,refugee_data['refugee'].max()+500])
YLIM = [0,1000]
ax[0].legend(loc='upper left')
ax2.legend(loc='lower right')
ax[0].set_ylim(YLIM)
fig.tight_layout()

burundi_gdf.plot(ax=ax[1],color='blue',alpha=0.2)
EPS = 0.1
SCALE = 30
conflict_data_gdf = gpd.GeoDataFrame(conflict_data,geometry=gpd.points_from_xy(conflict_data.longitude,conflict_data.latitude))
conflict_data_gdf.plot(ax=ax[1],color='red',alpha=0.2,markersize=(conflict_data['fatalities']+EPS)*SCALE)
ax[1].set_xlim(burundi_gdf.total_bounds[0], burundi_gdf.total_bounds[2])
ax[1].set_ylim(burundi_gdf.total_bounds[1], burundi_gdf.total_bounds[3])
fig.tight_layout()

# %%
all_ids = burundi_gdf['shapeName'].tolist()

# %%
def get_results_for_2(hyper_comb, who='refugee',region_name=["all"],prefix='fresh_calib_batch_simulation',look_until=100,ROLL=7):
    
    search_in_ids = all_ids
    if region_name!=["all"]:
        search_in_ids = region_name
    
    all_dfs = []
    found = 0
    for cur_id in search_in_ids:
        
        f_name = prefix+'_completed_'+str(cur_id)+'_'+str(hyper_comb).zfill(5)+'.csv'
        print(f_name)
        if os.path.isfile(OUTPUT_DIR+f_name):
            true_f_name = f_name
        else:
            continue
            
        cur_df = pd.read_csv(OUTPUT_DIR+true_f_name)
        cur_df['time'] = pd.to_datetime(cur_df['time'])
        all_dfs.append(cur_df)
        found = found + 1
    
    ovr_df = pd.concat(all_dfs)
    ovr_df = ovr_df.groupby('time')[who].sum().reset_index()
    ovr_df[who] = ovr_df[who].rolling(ROLL).mean()
    #print(ovr_df.columns.tolist())
    ovr_df = ovr_df.dropna(subset=[who])
    print(found,'raions found')
    return ovr_df

#get_results_for(777,prefix='mim')
def get_uncertainty_results(hyper_comb, region_name="all",prefix='fresh_calib_batch_simulation'):
    all_dfs = []
    if region_name=="all":
        col_to_sum = ['refugee','old_people','child','male','female']
        for cur_id in all_ids:
            f_name = prefix+'_result_completed_'+str(cur_id)+'_'+str(hyper_comb).zfill(5)+'.csv'
            if os.path.isfile(OUTPUT_DIR+f_name):
                cur_df = pd.read_csv(OUTPUT_DIR+f_name)
                cur_df['time'] = pd.to_datetime(cur_df['time'])
                cur_df = cur_df.sort_values(by=['time','refugee'],ascending=[True,False])
                
                cur_df = cur_df.drop_duplicates(subset=['time'],keep='first')
                all_dfs.append(cur_df)
    return all_dfs

# %% [markdown]
# ## UNCERTAINTY PLOTS FOR MIM FO

# %% [markdown]
# #### Create the data

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

plt.style.use('classic')
import seaborn as sns
sns.set()

def get_uncertainty(sim_indices,first_df,q1=0.25,q3=0.75):
    #first_df = first_df[0:sz]
    run_cols = [str(i) for i in sim_indices if str(i) in first_df.columns.tolist()]
    medians = first_df[run_cols].median(axis=1)
    q1 = first_df[run_cols].quantile(q1, axis=1)
    q3 = first_df[run_cols].quantile(q3, axis=1)
    return medians,q1,q3

#simulation_indices = [10060,10061,10062,10063,10064,10065,10066,10067,10068,10069]
#simulation_indices = [30000,30001,30002,30003,30004,30005,30006]
#simulation_indices = [40000,40001,40002,40003,40004,40005,40006]
#simulation_indices = [50000,50001,50002,50003,50004,50005,50006]
#simulation_indices = [50006,50007,50008,50009,50010,50011]
#simulation_indices = [2000,2001,2004,2005]

# %%
simulation_indices = [89999,89998,89997]

first_df = []
second_df = []

for vv in simulation_indices:
    print(vv,end=' ')
    try:
        current_df = get_results_for_2(vv,prefix='mim_result',ROLL=ROLLING)
        current_df['comb'] = str(vv)
        #current_df_unsmoothed = get_results_for(vv,prefix='mim_result',ROLL=1)
        #current_df_unsmoothed['comb'] = str(vv)
        
        first_df.append(current_df)
        #second_df.append(current_df_unsmoothed)
        
    except:
        continue
first_df = pd.concat(first_df).pivot(index='time',columns='comb',values='refugee').reset_index().fillna(0)
#second_df = pd.concat(second_df).pivot(index='time',columns='comb',values='refugee').reset_index().fillna(0)
# Out:
# 89999 89998 89997
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-d20a9b1ad741> in <module>
#      17     except:
#      18         continue
# ---> 19 first_df = pd.concat(first_df).pivot(index='time',columns='comb',values='refugee').reset_index().fillna(0)
#      20 #second_df = pd.concat(second_df).pivot(index='time',columns='comb',values='refugee').reset_index().fillna(0)
#
# ~/.conda/envs/biocomplexity/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
#     283         copy=copy,
# --> 284         sort=sort,
#     285     )
#     286
#
# ...

# %%
# set1 =

# %%
import datetime
#median_normal,q1_normal,q3_normal = get_uncertainty(simulation_indices[0:3],first_df)
#median_esc,q1_esc,q3_esc = get_uncertainty(simulation_indices[5:-2],first_df)
#2000 good, 2004 good #2008 may be good #2012 good
#check_single = 2018

trim = 7

# median_normal,q1_normal,q3_normal = get_uncertainty(simulation_indices[0:10-trim],first_df)
# median_esc,q1_esc,q3_esc = get_uncertainty(simulation_indices[10:-trim],first_df)

# median_normal_unsmooth,q1_normal_unsmooth,q3_normal_unsmooth = get_uncertainty(simulation_indices[0:10-trim],second_df)
# median_esc_unsmooth,q1_esc_unsmooth,q3_esc_unsmooth = get_uncertainty(simulation_indices[10:-trim],second_df)

# median_normal,q1_normal,q3_normal = get_uncertainty([check_single],first_df)
# median_esc,q1_esc,q3_esc = get_uncertainty([check_single+1],first_df)

from matplotlib import rcParams
from matplotlib.colors import LinearSegmentedColormap

fig,ax = plt.subplots(figsize=(10,5))
plt.xticks(rotation=60)
rcParams["font.family"] = "calibri"
rcParams["font.size"] = 12
rcParams["axes.labelsize"] = 16
rcParams["axes.titlesize"] = 20
rcParams["xtick.labelsize"] = 14
rcParams["ytick.labelsize"] = 14

ax.plot(refugee_df['time'], refugee_df['refugee'],label='Observed Border Crossing from Ukraine',linewidth=4,color='#2ca25f')

upto = 20
#50008 only 
phs = []
phs_idx = -1
Bad = [50026,50027,50047,50037,50038,50039,50003,50004,50005,50006,50007,
       50008,50009,50000,50001,50002,50012,50013,50036,
      50041,50011,50044,50042,50045,50043,50046,50022,50051,50052,50059,50060]
#for p in simulation_indices[0:7]:
all_rmse = []
all_pcc = []
#for p in [50091,50094,50096,50097,50098]:
for p in [50126]:
    if p in Bad:
        continue
    print(p,end=' ')
    phs_idx = phs_idx + 1
    try:
        runtime_df = pd.read_csv('../runtime_log/parameter_comb_comp_paper.csv')
        new_series = first_df[str(p)].copy()
        lo = runtime_df[runtime_df.hyper_comb==p].iloc[0]['BIAS_SCALE']
#         hi = runtime_df[runtime_df.hyper_comb==p].iloc[0]['THRESH_HI']
        ax.plot(first_df["time"], new_series,linewidth=2,label=str(p))
        
        estimated_df = new_series[5:61+5].reset_index()
        estimated = estimated_df[estimated_df.columns.tolist()[-1]]
        truth = refugee_df['refugee'].reset_index()['refugee']
        pcc = estimated.corr(truth)
        rmse = ((estimated - truth) ** 2).mean() ** .5
        print(lo,pcc,rmse)
        all_rmse.append(rmse)
        all_pcc.append(pcc)
    except Exception as e:
        print(e)
        continue
ax.legend(loc='best',ncol=3)
#ax.plot([1,2],[50000,400000],linewidth=10)
#print(ax.get_xticks())
#print(ax.get_xticklabels())
#ax.plot(first_df["time"], median_esc,label='Escalated Scenario',linewidth=2,color='#5e4fa2')

# ax.plot(second_df['time'],median_normal_unsmooth,linewidth=1,linestyle='dashed',color='#a50026',alpha=0.8)
# ax.plot(second_df['time'],median_esc_unsmooth,linewidth=1,linestyle='dashed',color='#5e4fa2',alpha=0.8)
# #ax.plot(first_df["time"], first_df['11018'],label='One simulation',linewidth=2,color='red')
# #ax.plot(first_impact_df['time'],first_impact_df['estimation'],label='Estimation with linear regression',linewidth=2,color='#662506')

# #gradient = np.linspace(0, 1, 256)
# #colors = plt.cm.get_cmap("terrain")(gradient)
# ax.fill_between(first_df["time"], q1_normal, q3_normal, color='#de77ae',alpha=0.5)
# ax.fill_between(first_df["time"], q1_esc, q3_esc, color='#66c2a5',alpha=0.5)

# ax.fill_between(second_df['time'], q1_normal_unsmooth, q3_normal_unsmooth, color='#de77ae',alpha=0.2)
# ax.fill_between(second_df["time"], q1_esc_unsmooth, q3_esc_unsmooth, color='#66c2a5',alpha=0.2)


# #ax.set_facecolor("#e0e0e0")

# # Add labels and legend
# ax.set_xlabel("Time",fontweight='bold')
# ax.set_ylabel("Number of Migrants",fontweight='bold')

# #ax.set_title("Daily Migrants from Ukraine generated by ABM model")
# ax.legend()
# #ax.set_yscale('log')

ax.set_xlim([datetime.date(2022, 3, 1), datetime.date(2022, 5, 6)])
print(ax.get_xticks())
#ax.set_ylim([0,320000])
# fig.tight_layout()
#fig.savefig('../Figures/policy_analysis.pdf')
# Out:
# 50126 0.54 0.9265527331512765 24311.317325308326
# [19052. 19059. 19066. 19073. 19083. 19090. 19097. 19104. 19113.]

# %%
import datetime
#median_normal,q1_normal,q3_normal = get_uncertainty(simulation_indices[0:3],first_df)
#median_esc,q1_esc,q3_esc = get_uncertainty(simulation_indices[5:-2],first_df)
#2000 good, 2004 good #2008 may be good #2012 good
#check_single = 2018

trim = 7

# median_normal,q1_normal,q3_normal = get_uncertainty(simulation_indices[0:10-trim],first_df)
# median_esc,q1_esc,q3_esc = get_uncertainty(simulation_indices[10:-trim],first_df)

# median_normal_unsmooth,q1_normal_unsmooth,q3_normal_unsmooth = get_uncertainty(simulation_indices[0:10-trim],second_df)
# median_esc_unsmooth,q1_esc_unsmooth,q3_esc_unsmooth = get_uncertainty(simulation_indices[10:-trim],second_df)

# median_normal,q1_normal,q3_normal = get_uncertainty([check_single],first_df)
# median_esc,q1_esc,q3_esc = get_uncertainty([check_single+1],first_df)

from matplotlib import rcParams
from matplotlib.colors import LinearSegmentedColormap




upto = 20
#50008 only 
phs = []
phs_idx = -1
Bad = [50026,50027,50047,50037,50038,50039,50003,50004,50005,50006,50007,
       50008,50009,50000,50001,50002,50012,50013,50036,
      50041,50011,50044,50042,50045,50043,50046,50022,50051,50052,50059,50060]
#for p in simulation_indices[0:7]:
all_rmse = []
all_pcc = []
#for p in [50091,50094,50096,50097,50098]:
for q in range(0,len(simulation_indices)):
    fig,ax = plt.subplots(figsize=(10,5))
    plt.xticks(rotation=60)
    rcParams["font.family"] = "calibri"
    rcParams["font.size"] = 12
    rcParams["axes.labelsize"] = 16
    rcParams["axes.titlesize"] = 20
    rcParams["xtick.labelsize"] = 14
    rcParams["ytick.labelsize"] = 14
    ax.plot(refugee_df['time'], refugee_df['refugee'],label='Observed Border Crossing from Ukraine',linewidth=4,color='#2ca25f')
    
    for p in simulation_indices[:q]:
        if p in Bad:
            continue
        print(p,end=' ')
        phs_idx = phs_idx + 1
        try:
            #runtime_df = pd.read_csv('../runtime_log/parameter_comb_comp_paper.csv')
            new_series = first_df[str(p)].copy()
            #lo = runtime_df[runtime_df.hyper_comb==p].iloc[0]['FIRST_PHASE_BORDER_CROSS_SCALE']
    #         hi = runtime_df[runtime_df.hyper_comb==p].iloc[0]['THRESH_HI']
            ax.plot(first_df["time"], new_series,linewidth=2,label=str(p),alpha=0.2)

            estimated_df = new_series[5:61+5].reset_index()
            estimated = estimated_df[estimated_df.columns.tolist()[-1]]
            truth = refugee_df['refugee'].reset_index()['refugee']
            pcc = estimated.corr(truth)
            rmse = ((estimated - truth) ** 2).mean() ** .5
            print(p,pcc,rmse)
            all_rmse.append(rmse)
            all_pcc.append(pcc)    
        except Exception as e:
            print(e)
            continue
    ax.plot(first_df["time"], first_df[str(simulation_indices[q])],linewidth=2,label=str(simulation_indices[q]))    
    ax.legend(loc='best',ncol=3)
    ax.set_xlim([datetime.date(2022, 3, 1), datetime.date(2022, 5, 6)])
    ax.set_ylim([0, 350000])
    fig.tight_layout()
    fig.savefig('../images/bayes_'+str(q).zfill(3)+'.png')
    
#ax.plot([1,2],[50000,400000],linewidth=10)
#print(ax.get_xticks())
#print(ax.get_xticklabels())
#ax.plot(first_df["time"], median_esc,label='Escalated Scenario',linewidth=2,color='#5e4fa2')

# ax.plot(second_df['time'],median_normal_unsmooth,linewidth=1,linestyle='dashed',color='#a50026',alpha=0.8)
# ax.plot(second_df['time'],median_esc_unsmooth,linewidth=1,linestyle='dashed',color='#5e4fa2',alpha=0.8)
# #ax.plot(first_df["time"], first_df['11018'],label='One simulation',linewidth=2,color='red')
# #ax.plot(first_impact_df['time'],first_impact_df['estimation'],label='Estimation with linear regression',linewidth=2,color='#662506')

# #gradient = np.linspace(0, 1, 256)
# #colors = plt.cm.get_cmap("terrain")(gradient)
# ax.fill_between(first_df["time"], q1_normal, q3_normal, color='#de77ae',alpha=0.5)
# ax.fill_between(first_df["time"], q1_esc, q3_esc, color='#66c2a5',alpha=0.5)

# ax.fill_between(second_df['time'], q1_normal_unsmooth, q3_normal_unsmooth, color='#de77ae',alpha=0.2)
# ax.fill_between(second_df["time"], q1_esc_unsmooth, q3_esc_unsmooth, color='#66c2a5',alpha=0.2)


# #ax.set_facecolor("#e0e0e0")

# # Add labels and legend
# ax.set_xlabel("Time",fontweight='bold')
# ax.set_ylabel("Number of Migrants",fontweight='bold')

# #ax.set_title("Daily Migrants from Ukraine generated by ABM model")
# ax.legend()
# #ax.set_yscale('log')


#print(ax.get_xticks())
#ax.set_ylim([0,320000])
# fig.tight_layout()
# Out:
# 1 1 0.9398721520609041 24639.215204946082
# 1 1 0.9398721520609041 24639.215204946082
# 2 2 0.902697562830496 44200.81681944105
# 1 1 0.9398721520609041 24639.215204946082
# 2 2 0.902697562830496 44200.81681944105
# 3 3 -0.7294965032549364 96288.69416254378
# 1 1 0.9398721520609041 24639.215204946082
# 2 2 0.902697562830496 44200.81681944105
# 3 3 -0.7294965032549364 96288.69416254378
# 4 4 0.9045006617264822 44211.16113025504
# 1 1 0.9398721520609041 24639.215204946082
# 2 2 0.902697562830496 44200.81681944105
# 3 3 -0.7294965032549364 96288.69416254378
# 4 4 0.9045006617264822 44211.16113025504
# 5 5 0.9055955143639169 34410.501732093675
# 1 1 0.9398721520609041 24639.215204946082
# 2 2 0.902697562830496 44200.81681944105
# 3 3 -0.7294965032549364 96288.69416254378
# 4 4 0.9045006617264822 44211.16113025504
# 5 5 0.9055955143639169 34410.501732093675
# 6 6 0.9106502309335256 27389.19282739808
# 1 1 0.9398721520609041 24639.215204946082
# 2 2 0.902697562830496 44200.81681944105
# ...

# %%
all_pcc.sort()
all_rmse.sort()

# %%
all_pcc
# Out:
# [0.9080876640874299,
#  0.9165323250576025,
#  0.9190014311086135,
#  0.9191460121490258,
#  0.9262731575881898,
#  0.9280275125548761]

# %%
all_rmse
# Out:
# [25453.376792590378,
#  25754.60514597671,
#  27184.106992310557,
#  28618.21661160198,
#  28684.198379191337,
#  29367.401783530426]

# %%
new_series
# Out:
# 0      5235.142857
# 1      6159.428571
# 2      5595.000000
# 3      6146.428571
# 4      6790.857143
#           ...
# 199       3.142857
# 200       5.857143
# 201       0.000000
# 202       0.000000
# 203       0.000000
# Name: 50060, Length: 204, dtype: float64

# %%
import seaborn as sns
import datetime
from matplotlib import rcParams
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.dates as mdates

fig,ax = plt.subplots(figsize=(8,5))
#plt.xticks(rotation=30)
rcParams["font.family"] = "calibri"
rcParams["font.size"] = 32
rcParams["axes.labelsize"] = 28
rcParams["axes.titlesize"] = 28
rcParams["xtick.labelsize"] = 26
rcParams["ytick.labelsize"] = 26

simulation_indices_without_bad = [i for i in simulation_indices if i not in Bad]

medians,q1,q3 = get_uncertainty(simulation_indices,first_df,q1=0.2,q3=0.8)
ax.plot(refugee_df['time'], refugee_df['refugee']/1000,label='Observed',linewidth=4,color='#2ca25f')
ax.plot(first_df["time"], medians/1000,label='ABM 2.0',linewidth=2,color='#3f007d')

gradient = np.linspace(0, 1, 256)
colors = plt.cm.get_cmap("terrain")(gradient)
ax.fill_between(first_df["time"], q1/1000, q3/1000, alpha=0.3, color='#3f007d')

medians,q1,q3 = get_uncertainty(prev_indices,first_df,q1=0.2,q3=0.8)
ax.plot(first_df["time"][5:], medians[5:]/1000,label='ABM',linewidth=2,color='#f03b20')

gradient = np.linspace(0, 1, 256)
colors = plt.cm.get_cmap("terrain")(gradient)
ax.fill_between(first_df["time"][5:], q1[5:]/1000, q3[5:]/1000, alpha=0.3, color='#f03b20')

myFmt = mdates.DateFormatter('%m-%d')
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(myFmt)

#ax.set_facecolor("white")
sns.set_style('whitegrid')
# Add labels and legend
#ax.set_xlabel("Time",fontweight='bold')
ax.set_ylabel("Migrants (1000s)",fontweight='bold',fontsize=32)

#ax.set_title("Daily Migrants from Ukraine generated by ABM model")
ax.legend(fontsize=26)
#ax.set_yscale('log')
ax.set_xlim([datetime.date(2022, 3, 1), datetime.date(2022, 5, 1)])
ax.set_ylim([0, 320])
ax.yaxis.grid(True)
ax.xaxis.grid(False)
fig.tight_layout()
#fig.savefig('../Figures/mim_result_with_lin_reg.pdf',dpi=350,bbox_inches='tight')

# %%
medians,q1,q3 = get_uncertainty(simulation_indices,first_df,q1=0.2,q3=0.8)
times = first_df['time'][5:61+5].reset_index()['time']
estimated_2 = medians[5:61+5].reset_index()[0]
truth = refugee_df['refugee'].reset_index()['refugee']
medians,q1,q3 = get_uncertainty(prev_indices,first_df,q1=0.2,q3=1)
estimated = medians[5:61+5].reset_index()[0]
print(estimated.corr(truth),estimated_2.corr(truth))
rmse_1 = ((estimated - truth) ** 2).mean() ** .5
rmse_2 = ((estimated_2 - truth) ** 2).mean() ** .5
print(rmse_1,rmse_2)
#print((((estimated - truth) ** 2)**0.5).var(ddof=0),(((estimated_2 - truth) ** 2)**0.5).var(ddof=0))
# Out:
# 0.9559017323758052 0.8999528140814195
# 29942.51660172184 25976.362673192947

# %%
df = pd.DataFrame(list(zip(times,estimated, estimated_2, truth)), columns =['Time','ABM', 'ABM_2','Truth'])
df['error'] = (abs(df['Truth'] - df['ABM']))/df['Truth']*100
df['error_2'] = abs(df['Truth'] - df['ABM_2'])/df['Truth']*100
df['jitse'] = df['error_2']<df['error']
df2 = df[1:54]
#df2

# %%
fig,ax = plt.subplots(figsize=(6,4))
df2[['error','error_2']].plot.box(ax=ax)
ax.set_ylabel('% error w.r.t Observed')
ax.set_xticklabels(['ABM','ABM 2.0'])
# Out:
# [Text(1, 0, 'ABM'), Text(2, 0, 'ABM 2.0')]

# %%
import seaborn as sns
import datetime
from matplotlib import rcParams
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.dates as mdates

fig,ax = plt.subplots(figsize=(10,6))
#plt.xticks(rotation=30)
rcParams["font.family"] = "calibri"
rcParams["font.size"] = 32
rcParams["axes.labelsize"] = 28
rcParams["axes.titlesize"] = 28
rcParams["xtick.labelsize"] = 26
rcParams["ytick.labelsize"] = 26


ax.plot(df2['Time'], (df2['Truth']-df2['ABM'])/df2['Truth']*100,color='#f03b20',label='ABM')
ax.plot(df2['Time'], (df2['Truth']-df2['ABM_2'])/df2['Truth']*100,color='#3f007d',label='ABM 2.0')
ax.axhline(y=0,color='gray')
myFmt = mdates.DateFormatter('%m-%d')
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(myFmt)

#ax.set_facecolor("white")
sns.set_style('whitegrid')
# Add labels and legend
#ax.set_xlabel("Time",fontweight='bold')
ax.legend(fontsize=16)
#ax.set_yscale('log')
ax.set_xlim([datetime.date(2022, 3, 8), datetime.date(2022, 4, 28)])
ax.set_ylim([-100, 100])
ax.yaxis.grid(True)
ax.xaxis.grid(False)
fig.tight_layout()
#fig.savefig('../Figures/mim_result_with_lin_reg.pdf',dpi=350,bbox_inches='tight')

# %%
estimated_2 = df2['ABM_2']
truth = df2['Truth']
estimated = df2['ABM']
print(estimated.corr(truth).round(2),estimated_2.corr(truth).round(2))
rmse_1 = ((estimated - truth) ** 2).mean() ** .5
rmse_2 = ((estimated_2 - truth) ** 2).mean() ** .5
print(rmse_1.round(4),rmse_2.round(4))
#print((((estimated - truth) ** 2)**0.5).var(ddof=0),(((estimated_2 - truth) ** 2)**0.5).var(ddof=0))
# Out:
# 0.96 0.91
# 31050.7752 25653.197

# %%
import pandas as pd
runtimes = pd.read_csv('../runtime_log/runtime_raion.csv')
abm_runtimes = runtimes[(runtimes.hyper_comb>=50000)]
abm_1_rt = abm_runtimes[abm_runtimes.hyper_comb<50022][['raion','runtime']].groupby('raion')['runtime'].mean().reset_index().sort_values(by='runtime')
abm_2_rt = abm_runtimes[abm_runtimes.hyper_comb>=50022][['raion','runtime']].groupby('raion')['runtime'].mean().reset_index().sort_values(by='runtime')

# %%
compare_runtime = abm_1_rt.merge(abm_2_rt,how='inner',on='raion').sort_values(by='runtime_y')
#compare_runtime = compare_runtime.sample(70)

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(32,12))
plt.xticks(rotation=90)
rcParams["font.size"] = 12

ind = np.arange(compare_runtime.shape[0])

width = 0.3  

# Plotting
ax.bar(ind, compare_runtime['runtime_x']/3600, width, label='ABM', color='#f03b20')
ax.bar(ind + width, compare_runtime['runtime_y']/3600, width, label='ABM 2.0',color='#3f007d' )
ax.set_xticks(ind)
ax.set_xticklabels(compare_runtime['raion'].tolist())
ax.set_xlim([0,compare_runtime.shape[0]])
ax.legend(loc='best',fontsize=20)
ax.set_ylabel('Runtime (seconds)')
fig.tight_layout()

# %%
test_raions = ['Zhytomyrskyi','Poltavskyi','Kyiv']
compare_runtime = compare_runtime[compare_runtime.raion.isin(test_raions)]

import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(10,6))
plt.xticks(rotation=15)
rcParams["font.size"] = 12

ind = np.arange(compare_runtime.shape[0])

width = 0.3  

# Plotting
ax.bar(ind, compare_runtime['runtime_x']/3600, width, label='ABM', color='#f03b20')
ax.bar(ind + width, compare_runtime['runtime_y']/3600, width, label='ABM 2.0',color='#3f007d' )
ax.set_xticks(ind+width/2)
ax.set_xticklabels(compare_runtime['raion'].tolist())
#ax.set_xlim([width/2,compare_runtime.shape[0]])
ax.legend(loc='best',fontsize=20)
ax.set_ylabel('Runtime (seconds)')
fig.tight_layout()

# %%
# runtime_df = pd.read_csv('../runtime_log/runtime_raion.csv')

# for vv in test_idx:
#     print(vv)
#     cur_runtime_df = runtime_df[runtime_df.hyper_comb==vv]
#     ll = cur_runtime_df.sort_values(by='runtime',ascending=False).head(10)['raion'].tolist()
#     ll.sort()
#     print(ll)

# %%
# %%time
all_raion_timing_data_df_ABM = []

for raion in all_ids:
    try:
        cur_timing_data_df = pd.read_csv(OUTPUT_DIR+'timing_log_'+str(raion)+'_50021'+'.csv')
        cur_timing_data_df['raion'] = raion
        all_raion_timing_data_df_ABM.append(cur_timing_data_df)
    except:
        continue
all_timing_log_df = pd.concat(all_raion_timing_data_df_ABM)
all_timing_log_df
# Out:
# CPU times: user 206 ms, sys: 6.1 ms, total: 212 ms
# Wall time: 280 ms
#     step  remaining_household_agent  remaining_person_agent  \
# 0    1.0                   178071.0                427575.0
# 1    2.0                   177881.0                427073.0
# 2    3.0                   177692.0                426567.0
# 3    4.0                   177529.0                426151.0
# 4    5.0                   177352.0                425679.0
# ..   ...                        ...                     ...
# 7   65.0                     9700.0                 24902.0
# 8   66.0                     9694.0                 24886.0
# 9   67.0                     9675.0                 24837.0
# 10  68.0                     9666.0                 24814.0
# 11  69.0                     9660.0                 24796.0
#
#     conflict_events_now  network_nodes  network_edges  attitude_time  \
# 0                 815.0       178071.0   3.170928e+10       3.360240
# ...

# %%
# %%time
all_raion_timing_data_df_ABM_2 = []

for raion in all_ids:
    try:
        cur_timing_data_df = pd.read_csv(OUTPUT_DIR+'timing_log_'+str(raion)+'_50055'+'.csv')
        cur_timing_data_df['raion'] = raion
        all_raion_timing_data_df_ABM_2.append(cur_timing_data_df)
    except:
        continue
all_timing_log_df_2 = pd.concat(all_raion_timing_data_df_ABM_2)
all_timing_log_df_2
# Out:
# CPU times: user 204 ms, sys: 3.88 ms, total: 208 ms
# Wall time: 288 ms
#     step  remaining_household_agent  remaining_person_agent  \
# 0    4.0                   178071.0                427575.0
# 1    5.0                   178002.0                427383.0
# 2    6.0                   177943.0                427217.0
# 3    7.0                   177889.0                427074.0
# 4    8.0                   177829.0                426917.0
# ..   ...                        ...                     ...
# 4   65.0                     9763.0                 25075.0
# 5   66.0                     9760.0                 25067.0
# 6   67.0                     9757.0                 25059.0
# 7   68.0                     9757.0                 25059.0
# 8   69.0                     9757.0                 25059.0
#
#     conflict_events_now  network_nodes  network_edges  attitude_time  \
# 0                 739.0       178071.0   3.170928e+10       3.986750
# ...

# %%
raion_to_check = 'Zhytomyrskyi'

pre_runtimes = all_timing_log_df[all_timing_log_df.raion==raion_to_check].sort_values(by='step')
post_runtimes = all_timing_log_df_2[all_timing_log_df_2.raion==raion_to_check].sort_values(by='step')

fig,ax = plt.subplots(1,2,figsize=(16,6))

for c in pre_runtimes.columns.tolist():
    if c.endswith('time'):
        ax[0].plot(pre_runtimes['step'],pre_runtimes[c],label=c)
        ax[1].plot(post_runtimes['step'],post_runtimes[c],label=c)

for i in range(0,2):
    ax[i].set_xlabel('Simulation Step')
    ax[i].set_ylabel('Time (seconds)')
    ax[i].set_yscale('log')
    ax[i].legend(fontsize=14,loc='lower right')
fig.tight_layout()

# %%
all_timing_log_df.sort_values(by='step').head(119)
# Out:
#     step  remaining_household_agent  remaining_person_agent  \
# 0    0.0                   203107.0                580526.0
# 0    0.0                   214178.0                557561.0
# 0    0.0                    80420.0                212096.0
# 0    0.0                   102539.0                250952.0
# 0    0.0                   139217.0                378622.0
# ..   ...                        ...                     ...
# 3    4.0                   177529.0                426151.0
# 4    4.0                    73810.0                148489.0
# 4    4.0                   198167.0                477054.0
# 4    4.0                   430874.0               1289327.0
# 4    4.0                   249499.0                646349.0
#
#     conflict_events_now  network_nodes  network_edges  attitude_time  \
# 0                 610.0       203107.0   4.125245e+10     134.605330
# 0                 610.0       214178.0   4.587222e+10     313.750369
# ...

# %%
all_timing_log_df['raion'].unique().shape
# Out:
# (119,)

# %%
fig,ax = plt.subplots(figsize=(12,6))
plt.xticks(rotation=60)
rcParams["font.family"] = "calibri"
rcParams["font.size"] = 12
rcParams["axes.labelsize"] = 16
rcParams["axes.titlesize"] = 20
rcParams["xtick.labelsize"] = 14
rcParams["ytick.labelsize"] = 14

all_time_cols = [x for x in all_timing_log_df.columns.tolist() if x.endswith('time')]
print(all_time_cols)

cols = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00']

ii = 0

time_of_int = 'attitude_time'
#for col in all_time_cols:
ax.boxplot([all_timing_log_df['attitude_time'],all_timing_log_df['pcb_time'],all_timing_log_df['subjective_norm_time'],all_timing_log_df['pre_time'],all_timing_log_df['post_time']])
#ax.scatter(all_timing_log_df['remaining_household_agent']*all_timing_log_df['conflict_events_now'],all_timing_log_df[time_of_int],label=time_of_int,color=cols[ii],alpha=0.2)
ii = ii + 1
ax.legend(loc='best')
#ax.set_yscale('log')
ax.set_xticklabels(all_time_cols)
# Out:
# No handles with labels found to put in legend.
# ['attitude_time', 'pcb_time', 'subjective_norm_time', 'pre_time', 'post_time']
# [Text(1, 0, 'attitude_time'),
#  Text(2, 0, 'pcb_time'),
#  Text(3, 0, 'subjective_norm_time'),
#  Text(4, 0, 'pre_time'),
#  Text(5, 0, 'post_time')]

# %%
all_timing_log_df.sort_values(by='subjective_norm_time',ascending=False).head(20)
# Out:
#     step  remaining_household_agent  remaining_person_agent  \
# 5    8.0                   273201.0                624602.0
# 4    7.0                   273471.0                625479.0
# 2    5.0                   274030.0                627306.0
# 1    4.0                   274322.0                628280.0
# 0    3.0                   274572.0                629092.0
# 6    9.0                   272940.0                623745.0
# 3    6.0                   273746.0                626374.0
# 7   10.0                   272664.0                622845.0
# 12  15.0                   271375.0                618602.0
# 10  13.0                   271904.0                620332.0
# 13  16.0                   271049.0                617527.0
# 14  17.0                   268921.0                610335.0
# 9   12.0                   272158.0                621182.0
# 15  18.0                   267660.0                606075.0
# 11  14.0                   271642.0                619464.0
# ...

# %%
all_timing_log_df[all_timing_log_df.raion=='Kalmiuskyi'].head(20)
# Out:
#     step  remaining_household_agent  remaining_person_agent  \
# 0    0.0                    81075.0                172143.0
# 1    1.0                    81033.0                172023.0
# 2    2.0                    80989.0                171896.0
# 3    3.0                    80941.0                171754.0
# 4    4.0                    80605.0                171012.0
# 5    5.0                    56042.0                106323.0
# 6    6.0                    48028.0                 89158.0
# 7    7.0                    42211.0                 76856.0
# 8    8.0                    37444.0                 66846.0
# 9    9.0                    33829.0                 59283.0
# 10  10.0                    30928.0                 53321.0
# 11  11.0                    28416.0                 48108.0
# 12  12.0                    26448.0                 44055.0
# 13  13.0                    24780.0                 40623.0
# 14  14.0                    23413.0                 37790.0
# ...

# %%
F = 0
df = 0
print(df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-ad58e2c8646c> in <module>
#       1 F = 0
#       2 df = 0
# ----> 3 print(df.columns.tolist())
#
# AttributeError: 'int' object has no attribute 'columns'

# %%
F = 0
df = 0
print(df.columns.tolist())

# %%
fig,ax = plt.subplots(figsize=(12,6))
plt.xticks(rotation=60)
rcParams["font.family"] = "calibri"
rcParams["font.size"] = 12
rcParams["axes.labelsize"] = 16
rcParams["axes.titlesize"] = 20
rcParams["xtick.labelsize"] = 14
rcParams["ytick.labelsize"] = 14

all_time_cols = [x for x in all_timing_log_df.columns.tolist() if x.endswith('time')]
print(all_time_cols)

cols = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00']

ii = 0

time_of_int = 'attitude_time'
#for col in all_time_cols:
#ax.boxplot([all_timing_log_df['attitude_time'],all_timing_log_df['pcb_time'],all_timing_log_df['subjective_norm_time'],all_timing_log_df['pre_time'],all_timing_log_df['post_time']])
ax.scatter(all_timing_log_df['step'],all_timing_log_df[time_of_int],label=time_of_int,color=cols[ii],alpha=0.2)
ii = ii + 1
ax.legend(loc='best')
#ax.set_yscale('log')
#ax.set_xticklabels(all_time_cols)
# Out:
# ['attitude_time', 'pcb_time', 'subjective_norm_time', 'pre_time', 'post_time']

# %%
all_timing_log_df[all_timing_log_df.subjective_norm_time>100].shape
# Out:
# (1422, 12)

# %%
all_timing_log_df.shape
# Out:
# (5453, 12)
