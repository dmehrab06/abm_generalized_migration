# %%
from bayes_opt import BayesianOptimization
from bayes_opt.logger import JSONLogger
from bayes_opt.event import Events
from bayes_opt.util import load_logs
from file_paths_and_consts import *

import pandas as pd
import os
import numpy as np
import random
import warnings
warnings.filterwarnings('ignore')
from bayes_opt import UtilityFunction
import json

SEED_VALUE = 590
random.seed(SEED_VALUE)

#OUTPUT_DIR

def get_memory(hh):
    if hh<=100000:
        return 16000
    if hh<=300000:
        return 64000
    return 256000

def get_core(hh):
    if hh<=100000:
        return 1
    if hh<=300000:
        return 4
    return 8

def get_results_for_2(hyper_comb, who='refugee',region_name=["all"],prefix='fresh_calib_batch_simulation',look_until=100,ROLL=7):
    
    search_in_ids = all_ids
    if region_name!=["all"]:
        search_in_ids = region_name
    
    all_dfs = []
    found = 0
    for cur_id in search_in_ids:
        f_name = prefix+'_completed_'+str(cur_id)+'_'+str(hyper_comb).zfill(5)+'.csv'
        f2_name = prefix+'_'+str(cur_id)+'_'+str(hyper_comb).zfill(5)+'.csv'
        if os.path.isfile(OUTPUT_DIR+f_name):
            true_f_name = f_name
        elif os.path.isfile(OUTPUT_DIR+f2_name):
            true_f_name = f2_name
        else:
            continue
            
        cur_df = pd.read_csv(OUTPUT_DIR+true_f_name)
        #print(cur_df.shape[0],end=' ')
        cur_df['time'] = pd.to_datetime(cur_df['time'])
        
        #cur_df = cur_df.sort_values(by=['time',who],ascending=[True,False])
        #cur_df = cur_df.drop_duplicates(keep='first')
        
        all_dfs.append(cur_df)
        found = found + 1
    
    ovr_df = pd.concat(all_dfs)
    ovr_df = ovr_df.groupby('time')[who].sum().reset_index()
    ovr_df[who] = ovr_df[who].rolling(ROLL).mean()
    #print(ovr_df.columns.tolist())
    ovr_df = ovr_df.dropna(subset=[who])
    print(found,'raions found')
    return ovr_df

ROLLING = 7
refugee_df = pd.read_csv(GROUND_TRUTH_DIR+'ukraine_refugee_data_2.csv')
refugee_df['time'] = pd.to_datetime(refugee_df['time'])
refugee_df['refugee'] = refugee_df['refugee'].rolling(ROLLING).mean()
refugee_df = refugee_df.dropna(subset=['refugee'])

cur_household_data = pd.read_csv(HOUSEHOLD_DIR+'ukraine_household_data.csv')
id_to_name = cur_household_data[['matching_place_id','matching_place_name']].drop_duplicates()
all_ids = []#cur_household_data.matching_place_id.unique().tolist()
#id_to_name['matching_place_name'].value_counts()
dict_id_to_name = dict(zip(id_to_name.matching_place_id, id_to_name.matching_place_name))

neighbor_adm2 = pd.read_csv(UNCLEANED_DATA_DIR+'neighbor_raions.csv')
all_ids = all_ids + neighbor_adm2.ADM2_EN_x.unique().tolist()

abm_pbounds = {
    'D':(1.0,5.0),
    'A':(30.0,70.0),
    'T':(0.5,3.0),
    'S':(0.01,1.0),
    #'t_l':(5,21),
    't_r':(1,14),
    'ps':(0.0,1.0),
    'ews':(0.0,1.0),
    #'pactive':(0,60),
    #'p_hi':(20,100),
    #'p_lo':(0,10),
    #'phase_shift':(0,60),
    'b_prob':(0.2,0.4),
    #'m_lo':(0.7,1.0),
    #'m_hi':(1.5,2.0),
}

network_struct = 13
dynamic_network = 1
use_neighbor = 5#random.sample([2,5,8,10],1)[0]#random.unifrom(0.0,1.0)

optimizer = BayesianOptimization(
    f=None,
    pbounds=abm_pbounds,
    verbose=2,
    random_state=3,
)
utility = UtilityFunction(kind="ucb", kappa=2.5, xi=0.0)
load_logs(optimizer, logs=["./logs/bayes_examples_all_log_revised.json"])
print("ABM Optimizer is now aware of {} points.".format(len(optimizer.space)))
logger = JSONLogger(path="./logs/bayes_examples_current_log.json")
optimizer.subscribe(Events.OPTIMIZATION_STEP, logger)
next_point_to_probe = optimizer.suggest(utility)
print("Next point to probe is:", next_point_to_probe)
# Out:
# ABM Optimizer is now aware of 0 points.
# Next point to probe is: {'A': 52.03191610298302, 'D': 3.8325912904724193, 'S': 0.2979956915238149, 'T': 1.7770690129941575, 'b_prob': 0.378589390869531, 'ews': 0.8962930889334381, 'ps': 0.12558531046383625, 't_r': 3.694157415796428}

# %%
for it in range(0,200):
    print('it',it)
    optimizer = BayesianOptimization(
        f=None,
        pbounds=abm_pbounds,
        verbose=2,
        random_state=3,
    )

    utility = UtilityFunction(kind="ucb", kappa=2.5, xi=0.0)
    load_logs(optimizer, logs=["./logs/bayes_examples_all_log_revised.json"])
    print("ABM Optimizer is now aware of {} points.".format(len(optimizer.space)))
    logger = JSONLogger(path="./logs/bayes_examples_current_log.json")
    optimizer.subscribe(Events.OPTIMIZATION_STEP, logger)
    next_point_to_probe = optimizer.suggest(utility)
    print("Next point to probe is:", next_point_to_probe)

    hyper_comb = len(optimizer.space)+5000
    print('job finished for',hyper_comb)
    res = get_results_for_2(hyper_comb,prefix='mim_result')
    comp_df = res.merge(refugee_df,on='time',how='inner')

    comp_df['diff'] = (comp_df['refugee_y']-comp_df['refugee_x'])**2
    rmse = ((comp_df[5:10]['diff'].sum()+comp_df[50:55]['diff'].sum())/10)**0.5 #10 data points
    #rmse = comp_df['diff'].mean()**0.5 #10 data points
    target = -rmse
    print("Found the target value to be:", target)

    optimizer.register(
        params=next_point_to_probe,
        target=target,
    )

    with open('./logs/bayes_examples_current_log.json') as json_file:
        data = json.load(json_file)
    print(data)
    with open('./logs/bayes_examples_all_log_revised.json', "a") as f:
        f.write(json.dumps(data) + "\n")
# Out:
# it 0
# ABM Optimizer is now aware of 3 points.
# Next point to probe is: {'A': 35.59796905775781, 'D': 2.4805006878033344, 'S': 0.477851996041548, 'T': 0.9045439296845893, 'b_prob': 0.254776554935304, 'ews': 0.2103054471648722, 'ps': 0.05745050932177531, 't_r': 13.22439846387084}
# job finished for 5003
# 112 raions found
# Found the target value to be: -84403.50668523973
# {'target': -84403.50668523973, 'params': {'A': 35.59796905775781, 'D': 2.4805006878033344, 'S': 0.477851996041548, 'T': 0.9045439296845893, 'b_prob': 0.254776554935304, 'ews': 0.2103054471648722, 'ps': 0.05745050932177531, 't_r': 13.22439846387084}, 'datetime': {'datetime': '2023-08-11 14:50:21', 'elapsed': 0.0, 'delta': 0.0}}
# it 1
# ABM Optimizer is now aware of 4 points.
# Next point to probe is: {'A': 35.83135682158901, 'D': 1.975314621994496, 'S': 0.6771249438425256, 'T': 1.604233259583258, 'b_prob': 0.2673121207375944, 'ews': 0.13591274877065163, 'ps': 0.13688239164955684, 't_r': 13.212721357914402}
# job finished for 5004
# 113 raions found
# Found the target value to be: -58755.3268144902
# {'target': -58755.3268144902, 'params': {'A': 35.83135682158901, 'D': 1.975314621994496, 'S': 0.6771249438425256, 'T': 1.604233259583258, 'b_prob': 0.2673121207375944, 'ews': 0.13591274877065163, 'ps': 0.13688239164955684, 't_r': 13.212721357914402}, 'datetime': {'datetime': '2023-08-11 14:50:21', 'elapsed': 0.0, 'delta': 0.0}}
# it 2
# ABM Optimizer is now aware of 5 points.
# Next point to probe is: {'A': 35.74201546941337, 'D': 1.515726913804528, 'S': 0.7123212295642386, 'T': 1.4854961457858415, 'b_prob': 0.30326895232602685, 'ews': 0.42182028807992256, 'ps': 0.046939704082481826, 't_r': 13.341523721004673}
# job finished for 5005
# 112 raions found
# Found the target value to be: -65700.90486822903
# {'target': -65700.90486822903, 'params': {'A': 35.74201546941337, 'D': 1.515726913804528, 'S': 0.7123212295642386, 'T': 1.4854961457858415, 'b_prob': 0.30326895232602685, 'ews': 0.42182028807992256, 'ps': 0.046939704082481826, 't_r': 13.341523721004673}, 'datetime': {'datetime': '2023-08-11 14:50:22', 'elapsed': 0.0, 'delta': 0.0}}
# it 3
# ABM Optimizer is now aware of 6 points.
# Next point to probe is: {'A': 35.73513597446302, 'D': 1.9465399103324752, 'S': 0.11305211288075376, 'T': 2.024843037240669, 'b_prob': 0.36791805627981833, 'ews': 0.058841203414544796, 'ps': 0.09659373701125529, 't_r': 12.690343473660707}
# job finished for 5006
# 112 raions found
# Found the target value to be: -79916.48612434899
# {'target': -79916.48612434899, 'params': {'A': 35.73513597446302, 'D': 1.9465399103324752, 'S': 0.11305211288075376, 'T': 2.024843037240669, 'b_prob': 0.36791805627981833, 'ews': 0.058841203414544796, 'ps': 0.09659373701125529, 't_r': 12.690343473660707}, 'datetime': {'datetime': '2023-08-11 14:50:23', 'elapsed': 0.0, 'delta': 0.0}}
# it 4
# ABM Optimizer is now aware of 7 points.
# Next point to probe is: {'A': 34.966686910785015, 'D': 1.8703450898823206, 'S': 0.6083378110584436, 'T': 1.858860941355517, 'b_prob': 0.259650214236511, 'ews': 0.5324497179619253, 'ps': 0.015323197203745753, 't_r': 13.908949122631807}
# job finished for 5007
# 112 raions found
# Found the target value to be: -120859.74071903956
# {'target': -120859.74071903956, 'params': {'A': 34.966686910785015, 'D': 1.8703450898823206, 'S': 0.6083378110584436, 'T': 1.858860941355517, 'b_prob': 0.259650214236511, 'ews': 0.5324497179619253, 'ps': 0.015323197203745753, 't_r': 13.908949122631807}, 'datetime': {'datetime': '2023-08-11 14:50:23', 'elapsed': 0.0, 'delta': 0.0}}
# it 5
# ABM Optimizer is now aware of 8 points.
# 112 raions found
# Found the target value to be: -39281.69536201672
# {'target': -39281.69536201672, 'params': {'A': 37.83795348555886, 'D': 4.0765313780137085, 'S': 0.8602538061443894, 'T': 2.2933016415186795, 'b_prob': 0.3920900509844425, 'ews': 0.32382715276492136, 'ps': 0.9349824730561289, 't_r': 12.30057589440024}, 'datetime': {'datetime': '2023-08-11 14:50:36', 'elapsed': 0.0, 'delta': 0.0}}
# it 22
# ABM Optimizer is now aware of 25 points.
# Next point to probe is: {'A': 37.968883058573994, 'D': 3.7576947365403117, 'S': 0.7079894241500023, 'T': 2.554747965070461, 'b_prob': 0.34708587545912106, 'ews': 0.8784775098936577, 'ps': 0.9393352942375374, 't_r': 12.491550939428377}
# job finished for 5025
# 112 raions found
# Found the target value to be: -30768.826669045997
# {'target': -30768.826669045997, 'params': {'A': 37.968883058573994, 'D': 3.7576947365403117, 'S': 0.7079894241500023, 'T': 2.554747965070461, 'b_prob': 0.34708587545912106, 'ews': 0.8784775098936577, 'ps': 0.9393352942375374, 't_r': 12.491550939428377}, 'datetime': {'datetime': '2023-08-11 14:50:37', 'elapsed': 0.0, 'delta': 0.0}}
# it 23
# ABM Optimizer is now aware of 26 points.
# Next point to probe is: {'A': 38.29443558914049, 'D': 4.083858200726395, 'S': 0.7474840266525533, 'T': 2.131976022721514, 'b_prob': 0.2537273596235659, 'ews': 1.0, 'ps': 1.0, 't_r': 12.299702488391208}
# job finished for 5026
# 112 raions found
# Found the target value to be: -28671.16816135566
# {'target': -28671.16816135566, 'params': {'A': 38.29443558914049, 'D': 4.083858200726395, 'S': 0.7474840266525533, 'T': 2.131976022721514, 'b_prob': 0.2537273596235659, 'ews': 1.0, 'ps': 1.0, 't_r': 12.299702488391208}, 'datetime': {'datetime': '2023-08-11 14:50:37', 'elapsed': 0.0, 'delta': 0.0}}
# it 24
# ABM Optimizer is now aware of 27 points.
# Next point to probe is: {'A': 38.53606695713209, 'D': 4.13910817818951, 'S': 0.5470502381596573, 'T': 2.7086179779165787, 'b_prob': 0.2, 'ews': 0.6412390163422448, 'ps': 1.0, 't_r': 12.371802823047247}
# job finished for 5027
# 112 raions found
# Found the target value to be: -65659.76766267397
# {'target': -65659.76766267397, 'params': {'A': 38.53606695713209, 'D': 4.13910817818951, 'S': 0.5470502381596573, 'T': 2.7086179779165787, 'b_prob': 0.2, 'ews': 0.6412390163422448, 'ps': 1.0, 't_r': 12.371802823047247}, 'datetime': {'datetime': '2023-08-11 14:50:38', 'elapsed': 0.0, 'delta': 0.0}}
# it 25
# ABM Optimizer is now aware of 28 points.
# Next point to probe is: {'A': 37.853922098476055, 'D': 3.643317666699227, 'S': 0.9742333441331564, 'T': 2.0009658322853388, 'b_prob': 0.4, 'ews': 0.9978116018593721, 'ps': 1.0, 't_r': 12.111726792546527}
# job finished for 5028
# 112 raions found
# Found the target value to be: -23228.652803450856
# {'target': -36475.10723037489, 'params': {'A': 38.09743806992491, 'D': 1.4016940966266782, 'S': 0.6344495984819732, 'T': 0.9792191027901724, 'b_prob': 0.3771032888593854, 'ews': 0.36298957398429554, 'ps': 0.9265466358710651, 't_r': 13.07608686511608}, 'datetime': {'datetime': '2023-08-11 14:51:00', 'elapsed': 0.0, 'delta': 0.0}}
# it 55
# ABM Optimizer is now aware of 58 points.
# Next point to probe is: {'A': 38.90936994293179, 'D': 1.679515655899419, 'S': 0.831461482332826, 'T': 1.0948640698940713, 'b_prob': 0.30858774926638316, 'ews': 0.21627618744132926, 'ps': 0.9548253583367619, 't_r': 13.16415894713665}
# job finished for 5058
# 112 raions found
# Found the target value to be: -64828.39514148417
# {'target': -64828.39514148417, 'params': {'A': 38.90936994293179, 'D': 1.679515655899419, 'S': 0.831461482332826, 'T': 1.0948640698940713, 'b_prob': 0.30858774926638316, 'ews': 0.21627618744132926, 'ps': 0.9548253583367619, 't_r': 13.16415894713665}, 'datetime': {'datetime': '2023-08-11 14:51:01', 'elapsed': 0.0, 'delta': 0.0}}
# it 56
# ABM Optimizer is now aware of 59 points.
# Next point to probe is: {'A': 38.62738978318316, 'D': 1.3883238913293354, 'S': 0.27580173161140215, 'T': 0.8929745143521385, 'b_prob': 0.27993069609038645, 'ews': 0.26587931692938327, 'ps': 0.7996909406381856, 't_r': 12.503930961295803}
# job finished for 5059
# 112 raions found
# Found the target value to be: -21249.668662915035
# {'target': -21249.668662915035, 'params': {'A': 38.62738978318316, 'D': 1.3883238913293354, 'S': 0.27580173161140215, 'T': 0.8929745143521385, 'b_prob': 0.27993069609038645, 'ews': 0.26587931692938327, 'ps': 0.7996909406381856, 't_r': 12.503930961295803}, 'datetime': {'datetime': '2023-08-11 14:51:01', 'elapsed': 0.0, 'delta': 0.0}}
# it 57
# ABM Optimizer is now aware of 60 points.
# Next point to probe is: {'A': 38.990258886097536, 'D': 1.6051603858305397, 'S': 0.902101971508124, 'T': 0.956849893334039, 'b_prob': 0.399938929132875, 'ews': 0.017009778218719185, 'ps': 0.8143157062458298, 't_r': 12.162806864697755}
# job finished for 5060
# 112 raions found
# Found the target value to be: -47973.84456810709
# {'target': -47973.84456810709, 'params': {'A': 38.990258886097536, 'D': 1.6051603858305397, 'S': 0.902101971508124, 'T': 0.956849893334039, 'b_prob': 0.399938929132875, 'ews': 0.017009778218719185, 'ps': 0.8143157062458298, 't_r': 12.162806864697755}, 'datetime': {'datetime': '2023-08-11 14:51:02', 'elapsed': 0.0, 'delta': 0.0}}
# it 58
# ABM Optimizer is now aware of 61 points.
# Next point to probe is: {'A': 39.28438052661479, 'D': 1.5842822932035152, 'S': 0.053776056117591134, 'T': 1.4953594370825034, 'b_prob': 0.38799290096440536, 'ews': 0.30673676753379575, 'ps': 0.45103182618538884, 't_r': 12.384896570433405}
# job finished for 5061
# 112 raions found
# Found the target value to be: -18562.31688207624
# it 63
# ABM Optimizer is now aware of 66 points.
# Next point to probe is: {'A': 39.44548509739391, 'D': 1.8422309722014818, 'S': 0.9328499013465773, 'T': 1.1679544617534923, 'b_prob': 0.3870883126605272, 'ews': 0.7210641697766996, 'ps': 0.8686911081493288, 't_r': 12.68193894271575}
# job finished for 5066
# 112 raions found
# Found the target value to be: -36454.526448490236
# {'target': -36454.526448490236, 'params': {'A': 39.44548509739391, 'D': 1.8422309722014818, 'S': 0.9328499013465773, 'T': 1.1679544617534923, 'b_prob': 0.3870883126605272, 'ews': 0.7210641697766996, 'ps': 0.8686911081493288, 't_r': 12.68193894271575}, 'datetime': {'datetime': '2023-08-11 14:51:06', 'elapsed': 0.0, 'delta': 0.0}}
# it 64
# ABM Optimizer is now aware of 67 points.
# Next point to probe is: {'A': 40.25497253812871, 'D': 1.412261587281698, 'S': 0.6362355351155256, 'T': 0.7491097098019925, 'b_prob': 0.31527479920183066, 'ews': 0.5007715444161437, 'ps': 0.244410690880991, 't_r': 12.789722497475116}
# job finished for 5067
# 112 raions found
# Found the target value to be: -132084.69015322506
# {'target': -132084.69015322506, 'params': {'A': 40.25497253812871, 'D': 1.412261587281698, 'S': 0.6362355351155256, 'T': 0.7491097098019925, 'b_prob': 0.31527479920183066, 'ews': 0.5007715444161437, 'ps': 0.244410690880991, 't_r': 12.789722497475116}, 'datetime': {'datetime': '2023-08-11 14:51:07', 'elapsed': 0.0, 'delta': 0.0}}
# it 65
# ABM Optimizer is now aware of 68 points.
# Next point to probe is: {'A': 39.42714718867424, 'D': 2.3615830455851605, 'S': 0.852580652524493, 'T': 1.5053192707702843, 'b_prob': 0.3018240027093453, 'ews': 0.26029141598289385, 'ps': 0.4228141225757177, 't_r': 12.358499234571402}
# job finished for 5068
# 112 raions found
# Found the target value to be: -45084.63371217765
# {'target': -45084.63371217765, 'params': {'A': 39.42714718867424, 'D': 2.3615830455851605, 'S': 0.852580652524493, 'T': 1.5053192707702843, 'b_prob': 0.3018240027093453, 'ews': 0.26029141598289385, 'ps': 0.4228141225757177, 't_r': 12.358499234571402}, 'datetime': {'datetime': '2023-08-11 14:51:08', 'elapsed': 0.0, 'delta': 0.0}}
# it 66
# ABM Optimizer is now aware of 69 points.
# Next point to probe is: {'A': 39.393822659960556, 'D': 2.3254291757966947, 'S': 0.965821466637727, 'T': 0.9772070382081633, 'b_prob': 0.2559791324429256, 'ews': 0.44822326342476404, 'ps': 0.31849939663362015, 't_r': 13.17593862096488}
# job finished for 5069
# 112 raions found
# Found the target value to be: -17134.674009452418
# {'target': -17134.674009452418, 'params': {'A': 39.393822659960556, 'D': 2.3254291757966947, 'S': 0.965821466637727, 'T': 0.9772070382081633, 'b_prob': 0.2559791324429256, 'ews': 0.44822326342476404, 'ps': 0.31849939663362015, 't_r': 13.17593862096488}, 'datetime': {'datetime': '2023-08-11 14:51:09', 'elapsed': 0.0, 'delta': 0.0}}
# it 67
# ABM Optimizer is now aware of 70 points.
# Next point to probe is: {'A': 39.57738783720166, 'D': 2.196855085244684, 'S': 0.7132822631408733, 'T': 1.6795706960371286, 'b_prob': 0.3489465643524716, 'ews': 0.8664537072120296, 'ps': 0.46156529197319207, 't_r': 11.778366955875043}
# job finished for 5070
# 113 raions found
# Found the target value to be: -39998.674297699785
# {'target': -39998.674297699785, 'params': {'A': 39.57738783720166, 'D': 2.196855085244684, 'S': 0.7132822631408733, 'T': 1.6795706960371286, 'b_prob': 0.3489465643524716, 'ews': 0.8664537072120296, 'ps': 0.46156529197319207, 't_r': 11.778366955875043}, 'datetime': {'datetime': '2023-08-11 14:51:09', 'elapsed': 0.0, 'delta': 0.0}}
# it 68
# ABM Optimizer is now aware of 71 points.
# Next point to probe is: {'A': 39.905675221746755, 'D': 1.6341033026173353, 'S': 0.5975512918651551, 'T': 1.3702406876926623, 'b_prob': 0.28839284197907844, 'ews': 0.8151932269067714, 'ps': 0.49678082285409153, 't_r': 11.754859060287437}
# job finished for 5071
# 112 raions found
# Found the target value to be: -139744.28375923514
# {'target': -139744.28375923514, 'params': {'A': 39.905675221746755, 'D': 1.6341033026173353, 'S': 0.5975512918651551, 'T': 1.3702406876926623, 'b_prob': 0.28839284197907844, 'ews': 0.8151932269067714, 'ps': 0.49678082285409153, 't_r': 11.754859060287437}, 'datetime': {'datetime': '2023-08-11 14:51:10', 'elapsed': 0.0, 'delta': 0.0}}
# it 69
# ...
# it 179
# ABM Optimizer is now aware of 182 points.
# Next point to probe is: {'A': 39.66830741790224, 'D': 2.469376651434074, 'S': 0.40405538810082414, 'T': 2.0147395657474356, 'b_prob': 0.34988210125747765, 'ews': 0.6923530913234264, 'ps': 0.7646848498551956, 't_r': 9.066094770020866}
# job finished for 5182
# 112 raions found
# Found the target value to be: -60521.7455552556
# {'target': -60521.7455552556, 'params': {'A': 39.66830741790224, 'D': 2.469376651434074, 'S': 0.40405538810082414, 'T': 2.0147395657474356, 'b_prob': 0.34988210125747765, 'ews': 0.6923530913234264, 'ps': 0.7646848498551956, 't_r': 9.066094770020866}, 'datetime': {'datetime': '2023-08-11 14:52:26', 'elapsed': 0.0, 'delta': 0.0}}
# it 180
# ABM Optimizer is now aware of 183 points.
# Next point to probe is: {'A': 39.69526470955699, 'D': 2.4830977272527694, 'S': 0.7838841359983668, 'T': 2.401295838724209, 'b_prob': 0.2583093775188148, 'ews': 0.5631279989092014, 'ps': 0.40693107572765785, 't_r': 8.667017343322485}
# job finished for 5183
# 112 raions found
# Found the target value to be: -76249.77821754296
# {'target': -76249.77821754296, 'params': {'A': 39.69526470955699, 'D': 2.4830977272527694, 'S': 0.7838841359983668, 'T': 2.401295838724209, 'b_prob': 0.2583093775188148, 'ews': 0.5631279989092014, 'ps': 0.40693107572765785, 't_r': 8.667017343322485}, 'datetime': {'datetime': '2023-08-11 14:52:27', 'elapsed': 0.0, 'delta': 0.0}}
# it 181
# ABM Optimizer is now aware of 184 points.
# Next point to probe is: {'A': 36.69401975292258, 'D': 4.137738835702205, 'S': 0.5462917113773136, 'T': 0.7473597806772282, 'b_prob': 0.3453853966621146, 'ews': 0.44489742392540094, 'ps': 0.48753685636198396, 't_r': 12.430597497556676}
# job finished for 5184
# 112 raions found
# Found the target value to be: -75345.13472456775
# {'target': -75345.13472456775, 'params': {'A': 36.69401975292258, 'D': 4.137738835702205, 'S': 0.5462917113773136, 'T': 0.7473597806772282, 'b_prob': 0.3453853966621146, 'ews': 0.44489742392540094, 'ps': 0.48753685636198396, 't_r': 12.430597497556676}, 'datetime': {'datetime': '2023-08-11 14:52:27', 'elapsed': 0.0, 'delta': 0.0}}
# it 182
# ABM Optimizer is now aware of 185 points.
# Next point to probe is: {'A': 39.54194334100623, 'D': 2.868999488080728, 'S': 0.4279373574992048, 'T': 2.2999512836265334, 'b_prob': 0.2325538702428622, 'ews': 0.48105158984784296, 'ps': 9.422198209350261e-05, 't_r': 8.853551198034772}
# job finished for 5185
# 113 raions found
# Found the target value to be: -25752.608586593433
# {'target': -25752.608586593433, 'params': {'A': 39.54194334100623, 'D': 2.868999488080728, 'S': 0.4279373574992048, 'T': 2.2999512836265334, 'b_prob': 0.2325538702428622, 'ews': 0.48105158984784296, 'ps': 9.422198209350261e-05, 't_r': 8.853551198034772}, 'datetime': {'datetime': '2023-08-11 14:52:28', 'elapsed': 0.0, 'delta': 0.0}}
# it 183
# ABM Optimizer is now aware of 186 points.
# Next point to probe is: {'A': 38.70826748293952, 'D': 3.049133125229379, 'S': 0.4392883520095176, 'T': 1.1619764165896036, 'b_prob': 0.30426017750524853, 'ews': 0.9429984284269886, 'ps': 0.502309370444107, 't_r': 10.295119128601543}
# job finished for 5186
# 113 raions found
# Found the target value to be: -64047.766419672895
# {'target': -64047.766419672895, 'params': {'A': 38.70826748293952, 'D': 3.049133125229379, 'S': 0.4392883520095176, 'T': 1.1619764165896036, 'b_prob': 0.30426017750524853, 'ews': 0.9429984284269886, 'ps': 0.502309370444107, 't_r': 10.295119128601543}, 'datetime': {'datetime': '2023-08-11 14:52:29', 'elapsed': 0.0, 'delta': 0.0}}
# it 184
# ABM Optimizer is now aware of 187 points.
# Next point to probe is: {'A': 39.22249493438725, 'D': 2.21913934126345, 'S': 0.6684252433030817, 'T': 2.2415950038305037, 'b_prob': 0.3150650983506882, 'ews': 0.4964442820240789, 'ps': 0.5716569054650191, 't_r': 8.892225852407869}
# job finished for 5187
# 113 raions found
# Found the target value to be: -73510.42271769831
# {'target': -73510.42271769831, 'params': {'A': 39.22249493438725, 'D': 2.21913934126345, 'S': 0.6684252433030817, 'T': 2.2415950038305037, 'b_prob': 0.3150650983506882, 'ews': 0.4964442820240789, 'ps': 0.5716569054650191, 't_r': 8.892225852407869}, 'datetime': {'datetime': '2023-08-11 14:52:30', 'elapsed': 0.0, 'delta': 0.0}}
# it 185
# ABM Optimizer is now aware of 188 points.
# Next point to probe is: {'A': 39.73598400475371, 'D': 2.1739910234275857, 'S': 0.9813430525816248, 'T': 2.8036562476870133, 'b_prob': 0.3030172582013515, 'ews': 0.5073533589703192, 'ps': 0.22310675572780547, 't_r': 8.426817364174813}
# job finished for 5188
# 112 raions found
# Found the target value to be: -25278.501984605704
# {'target': -25278.501984605704, 'params': {'A': 39.73598400475371, 'D': 2.1739910234275857, 'S': 0.9813430525816248, 'T': 2.8036562476870133, 'b_prob': 0.3030172582013515, 'ews': 0.5073533589703192, 'ps': 0.22310675572780547, 't_r': 8.426817364174813}, 'datetime': {'datetime': '2023-08-11 14:52:31', 'elapsed': 0.0, 'delta': 0.0}}
# it 186
# ABM Optimizer is now aware of 189 points.
# Next point to probe is: {'A': 39.475818685279826, 'D': 2.7865596350507085, 'S': 0.32412539433134274, 'T': 2.1960653380295767, 'b_prob': 0.22943735014427857, 'ews': 0.6512881280435323, 'ps': 0.23018338849286393, 't_r': 8.853403436966568}
# job finished for 5189
# 112 raions found
# Found the target value to be: -26717.83923145656
# {'target': -26717.83923145656, 'params': {'A': 39.475818685279826, 'D': 2.7865596350507085, 'S': 0.32412539433134274, 'T': 2.1960653380295767, 'b_prob': 0.22943735014427857, 'ews': 0.6512881280435323, 'ps': 0.23018338849286393, 't_r': 8.853403436966568}, 'datetime': {'datetime': '2023-08-11 14:52:32', 'elapsed': 0.0, 'delta': 0.0}}
# it 187
# ABM Optimizer is now aware of 190 points.
# Next point to probe is: {'A': 39.69622523196791, 'D': 2.1551273232786787, 'S': 0.7267793255347071, 'T': 2.7465377155307507, 'b_prob': 0.3270681744090544, 'ews': 0.4763370995069683, 'ps': 0.0028373058061274816, 't_r': 8.432325230888564}
# job finished for 5190
# 112 raions found
# Found the target value to be: -141896.9105022001
# {'target': -141896.9105022001, 'params': {'A': 39.69622523196791, 'D': 2.1551273232786787, 'S': 0.7267793255347071, 'T': 2.7465377155307507, 'b_prob': 0.3270681744090544, 'ews': 0.4763370995069683, 'ps': 0.0028373058061274816, 't_r': 8.432325230888564}, 'datetime': {'datetime': '2023-08-11 14:52:33', 'elapsed': 0.0, 'delta': 0.0}}
# it 188
# ABM Optimizer is now aware of 191 points.
# Next point to probe is: {'A': 39.21275875045778, 'D': 1.882627616940335, 'S': 0.43580563377938597, 'T': 2.8351545730284236, 'b_prob': 0.2971531446841456, 'ews': 0.4110472084948149, 'ps': 0.5924969379791446, 't_r': 8.185349516022328}
# job finished for 5191
# 112 raions found
# Found the target value to be: -72676.17213428234
# {'target': -72676.17213428234, 'params': {'A': 39.21275875045778, 'D': 1.882627616940335, 'S': 0.43580563377938597, 'T': 2.8351545730284236, 'b_prob': 0.2971531446841456, 'ews': 0.4110472084948149, 'ps': 0.5924969379791446, 't_r': 8.185349516022328}, 'datetime': {'datetime': '2023-08-11 14:52:34', 'elapsed': 0.0, 'delta': 0.0}}
# it 189
# ABM Optimizer is now aware of 192 points.
# Next point to probe is: {'A': 39.81071723009225, 'D': 3.0805780055168417, 'S': 0.827005410916258, 'T': 2.9455693827340634, 'b_prob': 0.2705263070982498, 'ews': 0.43940620956856036, 'ps': 0.1345784117969181, 't_r': 9.461899590492783}
# job finished for 5192
# 112 raions found
# Found the target value to be: -46559.994657759715
# {'target': -46559.994657759715, 'params': {'A': 39.81071723009225, 'D': 3.0805780055168417, 'S': 0.827005410916258, 'T': 2.9455693827340634, 'b_prob': 0.2705263070982498, 'ews': 0.43940620956856036, 'ps': 0.1345784117969181, 't_r': 9.461899590492783}, 'datetime': {'datetime': '2023-08-11 14:52:35', 'elapsed': 0.0, 'delta': 0.0}}
# it 190
# ABM Optimizer is now aware of 193 points.
# Next point to probe is: {'A': 38.902723576799524, 'D': 2.6545664527202235, 'S': 0.7086173634134088, 'T': 1.9468108044390835, 'b_prob': 0.34044164953684214, 'ews': 0.29824177347172187, 'ps': 0.48460667046377315, 't_r': 8.256411171685183}
# job finished for 5193
# 112 raions found
# Found the target value to be: -36252.532486626056
# {'target': -36252.532486626056, 'params': {'A': 38.902723576799524, 'D': 2.6545664527202235, 'S': 0.7086173634134088, 'T': 1.9468108044390835, 'b_prob': 0.34044164953684214, 'ews': 0.29824177347172187, 'ps': 0.48460667046377315, 't_r': 8.256411171685183}, 'datetime': {'datetime': '2023-08-11 14:52:36', 'elapsed': 0.0, 'delta': 0.0}}
# it 191
# ABM Optimizer is now aware of 194 points.
# Next point to probe is: {'A': 38.54437662691608, 'D': 2.3930255875581095, 'S': 0.794834220855332, 'T': 2.051723878564016, 'b_prob': 0.3007384618110263, 'ews': 0.9984660328398491, 'ps': 0.5199819518192625, 't_r': 8.576848048915494}
# job finished for 5194
# 112 raions found
# Found the target value to be: -29257.625968458276
# {'target': -29257.625968458276, 'params': {'A': 38.54437662691608, 'D': 2.3930255875581095, 'S': 0.794834220855332, 'T': 2.051723878564016, 'b_prob': 0.3007384618110263, 'ews': 0.9984660328398491, 'ps': 0.5199819518192625, 't_r': 8.576848048915494}, 'datetime': {'datetime': '2023-08-11 14:52:36', 'elapsed': 0.0, 'delta': 0.0}}
# it 192
# ABM Optimizer is now aware of 195 points.
# Next point to probe is: {'A': 38.518220178693596, 'D': 2.8148362369552493, 'S': 0.6499671117419853, 'T': 2.1739899433989156, 'b_prob': 0.3382401143306089, 'ews': 0.6780430566560919, 'ps': 0.9720208494126131, 't_r': 8.874940811717007}
# job finished for 5195
# 112 raions found
# Found the target value to be: -31484.87626626538
# {'target': -31484.87626626538, 'params': {'A': 38.518220178693596, 'D': 2.8148362369552493, 'S': 0.6499671117419853, 'T': 2.1739899433989156, 'b_prob': 0.3382401143306089, 'ews': 0.6780430566560919, 'ps': 0.9720208494126131, 't_r': 8.874940811717007}, 'datetime': {'datetime': '2023-08-11 14:52:37', 'elapsed': 0.0, 'delta': 0.0}}
# it 193
# ABM Optimizer is now aware of 196 points.
# job finished for 5200
# 112 raions found
# Found the target value to be: -54353.01179669282
# {'target': -54353.01179669282, 'params': {'A': 38.51566582303554, 'D': 2.3325609074673643, 'S': 0.3316895162440654, 'T': 2.270158118668577, 'b_prob': 0.36597273502921585, 'ews': 0.8709961272485571, 'ps': 0.8400817724587378, 't_r': 9.428359275736979}, 'datetime': {'datetime': '2023-08-11 14:52:41', 'elapsed': 0.0, 'delta': 0.0}}
# it 198
# ABM Optimizer is now aware of 201 points.
# Next point to probe is: {'A': 38.981158723405805, 'D': 2.4460719403176214, 'S': 0.037846171711457294, 'T': 2.4897230164300206, 'b_prob': 0.2763445310574105, 'ews': 0.9509259603484521, 'ps': 0.9485338075581115, 't_r': 9.27293233701346}
# job finished for 5201
# 113 raions found
# Found the target value to be: -51284.67901651068
# {'target': -51284.67901651068, 'params': {'A': 38.981158723405805, 'D': 2.4460719403176214, 'S': 0.037846171711457294, 'T': 2.4897230164300206, 'b_prob': 0.2763445310574105, 'ews': 0.9509259603484521, 'ps': 0.9485338075581115, 't_r': 9.27293233701346}, 'datetime': {'datetime': '2023-08-11 14:52:42', 'elapsed': 0.0, 'delta': 0.0}}
# it 199
# ABM Optimizer is now aware of 202 points.
# Next point to probe is: {'A': 38.01818817348652, 'D': 1.9760103578047787, 'S': 0.1790919765818781, 'T': 2.253580410715987, 'b_prob': 0.2519373731612227, 'ews': 0.7752669198897226, 'ps': 0.7164292144502796, 't_r': 9.675913505166681}
# job finished for 5202
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-7571e9068614> in <module>
#      18     hyper_comb = len(optimizer.space)+5000
#      19     print('job finished for',hyper_comb)
# ---> 20     res = get_results_for_2(hyper_comb,prefix='mim_result')
#      21     comp_df = res.merge(refugee_df,on='time',how='inner')
#      22
#
# <ipython-input-3-51bcbe307b46> in get_results_for_2(hyper_comb, who, region_name, prefix, look_until, ROLL)
#      61         found = found + 1
#      62
# ---> 63     ovr_df = pd.concat(all_dfs)
#      64     ovr_df = ovr_df.groupby('time')[who].sum().reset_index()
#      65     ovr_df[who] = ovr_df[who].rolling(ROLL).mean()
#
# ~/.conda/envs/biocomplexity/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
#     283         copy=copy,
# --> 284         sort=sort,
#     285     )
#     286
#
# ~/.conda/envs/biocomplexity/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     329
#     330         if len(objs) == 0:
# --> 331             raise ValueError("No objects to concatenate")
#     332
#     333         if keys is None:
#
# ValueError: No objects to concatenate

# %%
import subprocess
subprocess_output = subprocess.run(["squeue","-u","zm8bh","--name=bayes_att"],capture_output=True)

print(len(str(subprocess_output)))

if len(str(subprocess_output))==226:
    
    if len(optimizer.space)>=0:

        print('deleting previous runs')
        all_files = [f for f in os.listdir(".") if f.endswith('.out')]
        all_files.sort()
        for f in all_files[0:-3]:
            os.remove(f)
        hyper_comb = len(optimizer.space)+1000
        print('job finished for',hyper_comb)
        res = get_results_for_2(hyper_comb,prefix='mim_result')
        comp_df = res.merge(refugee_df,on='time',how='inner')

        comp_df['diff'] = (comp_df['refugee_y']-comp_df['refugee_x'])**2
        rmse = ((comp_df[5:10]['diff'].sum()+comp_df[50:55]['diff'].sum())/10)**0.5 #10 data points
        #rmse = comp_df['diff'].mean()**0.5 #10 data points
        target = -rmse
        print("Found the target value to be:", target)

        optimizer.register(
            params=next_point_to_probe,
            target=target,
        )

        with open('./logs/bayes_examples_current_log.json') as json_file:
            data = json.load(json_file)
        print(data)
        with open('./logs/bayes_examples_all_log_revised.json', "a") as f:
            f.write(json.dumps(data) + "\n")

        optimizer = BayesianOptimization(
            f=None,
            pbounds=abm_pbounds,
            verbose=2,
            random_state=3,
        )
        utility = UtilityFunction(kind="ucb", kappa=2.5, xi=0.0)
        load_logs(optimizer, logs=["./logs/bayes_examples_all_log_revised.json"])
        print("ABM Optimizer is now aware of {} points.".format(len(optimizer.space)))
        logger = JSONLogger(path="./logs/bayes_examples_current_log.json")
        optimizer.subscribe(Events.OPTIMIZATION_STEP, logger)
        next_point_to_probe = optimizer.suggest(utility)
        print("Next point to probe is:", next_point_to_probe)

        #raion_df = pd.read_csv('/home/zm8bh/radiation_model/migration_shock/scripts/analysis_notebooks/memory_req_raion.csv')

    X = next_point_to_probe
    hyper_comb = len(optimizer.space)+1000

    f = open("bayesian_calibration_"+str(hyper_comb)+".sh", "w")

    D = X['D']
    A = X['A']
    S = X['S']
    T = X['T']
    t_r = int(X['t_r'])
    t_l = t_r
    ps = X['ps']
    ews = X['ews']
    pactive = 40
    peer_thresh_lo = 2
    peer_thresh_hi = 15
    border_cross_prob = X['b_prob']
    phase_shift = 40
    multiply_lo = 1.0
    multiply_hi = 1.8
    comment = 'Bayes_calibration_fewer_parameters_40_shift_'+str(hyper_comb)

    necessary_mem = pd.read_csv('/home/zm8bh/radiation_model/migration_shock/scripts/analysis_notebooks/memory_req_raion.csv')
    raion_df = pd.read_csv('hh_cnts.csv')

    raion_df = raion_df.sort_values(by='hh',ascending=False)
    raion_df['memory'] = raion_df['hh'].apply(lambda x: get_memory(x))
    raion_df['core'] = raion_df['hh'].apply(lambda x: get_core(x))
    raion_df = raion_df.merge(necessary_mem[['Raion','mem_need']],left_on='raion',right_on='Raion',how='inner')
    raion_df['memory'] = raion_df[["memory", "mem_need"]].max(axis=1)
    raion_df = raion_df.sort_values(by='hh',ascending=False)

    raion = raion_df['raion'].tolist()
    mem = raion_df['memory'].tolist()
    cc = raion_df['core'].tolist()

    partition = 1

    set1_raion = raion[0:partition]
    set1_mem = mem[0:partition]
    set1_cc = cc[0:partition]

    set2_raion = raion[partition:]
    set2_mem = mem[partition:]
    set2_cc = cc[partition:]
    set2_raion.reverse()
    set2_mem.reverse()
    set2_cc.reverse()

    for i in range(len(set1_raion)):
        name = set1_raion[i]
        mem_req = set1_mem[i]
        core_use = set1_cc[i]
        print('sbatch --mem='+str(mem_req)+' --cpus-per-task='+str(core_use)+' ukr_mim_mdm_sample.sbatch',end=' ',file=f)
        if name.startswith('Chornobyl'):
            print('"'+name+'"',hyper_comb,D,A,T,S,t_l,t_r,ps,ews,pactive,peer_thresh_lo,peer_thresh_hi,
                  network_struct,dynamic_network,use_neighbor,border_cross_prob,phase_shift,multiply_lo,multiply_hi,core_use,file=f)
        else:
            print(name,hyper_comb,D,A,T,S,t_l,t_r,ps,ews,pactive,peer_thresh_lo,peer_thresh_hi,
                  network_struct,dynamic_network,use_neighbor,border_cross_prob,phase_shift,multiply_lo,multiply_hi,core_use,file=f)


    for i in range(len(set2_raion)):
        name = set2_raion[i]
        mem_req = set2_mem[i]
        core_use = set2_cc[i]
        print('sbatch --mem='+str(mem_req)+' --cpus-per-task='+str(core_use)+' ukr_mim_mdm_sample.sbatch',end=' ',file=f)
        if name.startswith('Chornobyl'):
            print('"'+name+'"',hyper_comb,D,A,T,S,t_l,t_r,ps,ews,pactive,peer_thresh_lo,peer_thresh_hi,
                  network_struct,dynamic_network,use_neighbor,border_cross_prob,phase_shift,multiply_lo,multiply_hi,core_use,file=f)
        else:
            print(name,hyper_comb,D,A,T,S,t_l,t_r,ps,ews,pactive,peer_thresh_lo,peer_thresh_hi,
                  network_struct,dynamic_network,use_neighbor,border_cross_prob,phase_shift,multiply_lo,multiply_hi,core_use,file=f)

    f.close()
    
    df = pd.DataFrame(columns=['hyper_comb','DISTANCE_DECAY','SIGMOID_SCALAR','SIGMOID_EXPONENT','MEMORY_DECAY',
                               'TIME_LEFT','TIME_RIGHT','BIAS_SCALE','EVENT_WEIGHT_SCALE','PEER_AFFECT_ACTIVE_DAY',
                               'THRESH_HI','USE_NEIGHBOR','BORDER_CROSS_PROB','THRESH_LO','NETWORK_STRUCTURE','COMMENT',
                               'FIRST_PHASE_BORDER_CROSS_SCALE','SECOND_PHASE_BORDER_CROSS_SCALE'])

    new_row = {'hyper_comb':hyper_comb,'DISTANCE_DECAY':D,'SIGMOID_SCALAR':A,'SIGMOID_EXPONENT':T,'MEMORY_DECAY':S,'TIME_LEFT':t_l,
               'TIME_RIGHT':t_r,'BIAS_SCALE':ps,'EVENT_WEIGHT_SCALE':ews,'PEER_AFFECT_ACTIVE_DAY':pactive,
               'THRESH_HI':peer_thresh_hi,'THRESH_LO':peer_thresh_lo,'NETWORK_STRUCTURE':network_struct,
               'USE_NEIGHBOR':use_neighbor,'BORDER_CROSS_PROB':border_cross_prob,'FIRST_PHASE_BORDER_CROSS_SCALE':multiply_lo,
               'SECOND_PHASE_BORDER_CROSS_SCALE':multiply_hi,'COMMENT':comment}

    df = df.append(new_row,ignore_index=True)

    df.to_csv('../runtime_log/parameter_comb_bayes.csv', mode='a', index=False, header=False)
    
    print("job started for",hyper_comb)
    submit_output = subprocess.run(["bash","bayesian_calibration_"+str(hyper_comb)+".sh"],capture_output=True)
    print(submit_output)
else:
    print('exit program')
